# %%
# %pylab inline
import scipy
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # PCA

# %% [markdown]
# ### Obtención de la información

# %%
#lee la informacion
pobreza = pd.read_csv('pobreza.csv', sep = ' ', encoding = 'utf-8', na_values = ['#DIV/0!'] )
#Guarda los nombres de los municipios
municipios = pobreza["Municipio"]
print municipios
#matriz que guarda los valores de las columnas de Analfabetismo, Inasistencia Escolar, Alta Dependencia Económica
#Y Sin Fuente Agua Mejorada
Tasas = pobreza[["Analfabetismo", "Inasistencia.Escolar",
                 "Alta.Dependencia.Economica", "Sin.Fuente.Agua.Mejorada"]]
#interpola los datos faltantes
#TasasHom = TasasHom.fillna(0)
Tasas = Tasas.apply(pd.Series.interpolate)
mean = Tasas.mean(axis = 0)
#Tiene las los valores en este orden (No afecta el análisis PCA), presentados en un array: 
#Alta Dependencia Económica, Analfabetismo, 
#Inasistencia Escolar, Sin Fuente Agua Mejorada 
arrayTasas = np.array(Tasas)
# Out:
# 1                 Medell?n
# 2                Abejorral
# 3                 Abriaqui
# 4               Alejandr?a
# 5                    Amag?
# 6                   Amalfi
# 7                    Andes
# 8              Angel?polis
# 9                Angostura
# 10                   Anori
# 11    Santaf? de Antioquia
# 12                    Anza
# 13                Apartad?
# 14               Arboletes
# 15                Argelia*
# ...
# 1099       La Guadalupe (CD)*
# 1100           Cacahual (CD)*
# 1101    San Jos? del Guaviare
# 1102                  Calamar
# 1103              El Retorno*
# 1104               Miraflores
# 1105                     Mit?
# 1106                  Caruru*
# 1107                  Taraira
# 1108           Papunaua (CD)*
# 1109                 Yavarat?
# 1110           Puerto Carre?o
# 1111            La Primavera*
# 1112            Santa Rosalia
# 1113                 Cumaribo
# Name: Municipio, Length: 1113

# %% [markdown]
# ## Algoritmo Covarianza

# %%
#Algoritmo que devuelve la matriz de covarianza en base a un conjunto de datos presentado en una matriz(array2D)
def matrizCovarianza(data):
    #el tamaño de la muestra
    tam = len(data)
    dim = len(data[0])
    cov = np.zeros((dim, dim))
    #promedio vectorial
    mean = data.mean(axis = 0)
    #variables de iteración
    i = j = k = 0
    #itera sobre una dimension de la matriz
    for i in range(dim):
        #itera sobre la otra dimension de la matriz, hasta la diagonal
        #(aprovechando la simetría de la matriz de covarianza)
        for j in range(0,i+1):
            suma = 0
            #Calcula la sumatoria que determina el término i,j de la matriz
            for k in range(tam):
                a = (data[k][i] - mean[i])*(data[k][j] - mean[j])
                suma += a
            #asigna los valores a los cuadros diagonalmente simétricos de la matriz de covarianza    
            cov[j][i] = suma/(tam-1)
            cov[i][j] = suma/(tam-1)

    return cov

# %% [markdown]
# ## Matriz de covarianza del problema

# %%
#matriz de covarianza de los datos de tasas de homicidio de los departamentos de Colombia a través de los años
cova = matrizCovarianza(arrayTasas)

# %%
#Muestra visual de la matriz de covarianza a una potencia menor que 1 (para acentuar más los colores) 
#verifica la simetría
#imshow(sqrt(sqrt(sqrt(sqrt(cova)))))
imshow(cova**(0.0000000001))

# %% [markdown]
# Claramente habrán diferencias entre los autovalores de la matriz, faltará analizar si es tan significativa como para hacer una reducción de dimensionalidad

# %% [markdown]
# ## Cálculo de autovalores y autovectores

# %%
#saca los autovalores y autovectores de la matriz de covarianza
eig = np.linalg.eig(cova)
#valores propios con un numero asociado que indica la posición en la lista su autovector correspondiente
eigenValuesN = np.array([np.array([(eig[0])[k] , k]) for k in range(len(eig[0]))])
#Se ordena el array respecto a la columna de autovalores (de mayor a menor)
eigenValuesN = -eigenValuesN
eigenValuesN = -eigenValuesN[[eigenValuesN[:,0].argsort()]]

# %% [markdown]
# ## Reducción de la dimensionalidad

# %% [markdown]
# Se tendrá en cuenta el criterio del 90%
#
# Esto es, solo se analizarán los primeros n autovalores cuya sumatoria sea el 90% del total

# %%
#calcula el peso total de los auto valores (se escogerán los primeros n que sean el 90% del peso total)
pesoT = sum(eigenValuesN.T[0])
index = 0
ans = 0
while ans < 0.9:
    ans+= eigenValuesN[index][0]/pesoT
    print ans
    index += 1
#El index paró un índice atrás (el while tarda 1 index en reconocer que ya no hay ciclo)
index = index-1
index
# Out:
# 0.704957232479
# 0.888684207887
# 0.96136161696
# 2

# %% [markdown]
# ### Evidentemente se puede reducir la dimensionalidad del problema teniendo en cuenta únicamente los 3 primeros índices y la base ortonormal que provocan, teniendo una muy buena aproximación.

# %%
#valores propios que se van a tomar
eigenValuesN = eigenValuesN[:(index+1)]
print "EigenValues: \n"
print eigenValuesN
#vectores propios correspondientestn
eigenVects = (eig[1])[eigenValuesN.T[1].astype(int)]
print "\nEigenVectors: \n"
print eigenVects
#espacio de indices de los autovectores
linsp = eigenValuesN.T[1].astype(int)
linsp
# Out:
# EigenValues:
#
# [[ 0.06511981  0.        ]
#  [ 0.01697162  1.        ]
#  [ 0.00671351  2.        ]]
#
# EigenVectors:
#
# [[-0.27911513 -0.73669943  0.61243141 -0.06554741]
#  [-0.33355625 -0.50027352 -0.77473461 -0.19558354]
#  [-0.19410589 -0.09579283 -0.09974975  0.9711831 ]]
# array([0, 1, 2])

# %% [markdown]
# ## Determinación de los coeficientes para el el "vector de pobreza" de cada municipio

# %% [markdown]
# ## Para cada municipio se dará un vector con las componentes de la base ortonormal de vectores presentada anteriormente.
# Cada componente corresponderá a cada vector según la posición del array

# %%
#las componentes pueden ser sacadas con el producto punto del vector a caracterizar con el de la base ortonormal
for k in range(len(array(municipios))):
    print array(municipios)[k]
    comps = [ np.dot(array(arrayTasas[k][:]),eigenVects[j]) for j in linsp]
    print comps
# Out:
# Medellín
# [-0.15789035924125314, -0.24538146009226713, -0.061683942493869819]
# Abejorral
# [-0.22289068551170932, -0.47090821981139236, 0.27321037736613435]
# Abriaqui
# [-0.19616295401334, -0.36450719840319135, 0.32457595895620872]
# Alejandría
# [-0.2032872525758945, -0.38620136283165668, 0.28261415564765002]
# Amagá
# [-0.20359096593457243, -0.36111457930664459, -0.024910430376513359]
# Amalfi
# [-0.31120144096309865, -0.53894703466179195, 0.26121841701932347]
# Andes
# [-0.26310934243764184, -0.44511082710149658, 0.20791348252053138]
# Angelópolis
# [-0.28378223717592921, -0.44602129272452745, -0.062642468437854426]
# [-0.23210067934201745, -0.40216043838420351, -0.10668342730556732]
# Andalucía
# [-0.21930401953608672, -0.3217938584646548, -0.057118458816576748]
# Ansermanuevo
# [-0.33224720021940152, -0.52890431225246515, 0.13724027857779683]
# Argelia
# [-0.28341105669626832, -0.45422648802528798, 0.18856002576886868]
# Bolívar
# [-0.28010213616320989, -0.45546089079572499, 0.087830056058550765]
# Buenaventura
# [-0.28733982912452655, -0.44482211221983031, 0.092855732026165427]
# Buga
# [-0.15894725385632083, -0.23196955435625805, -0.055565708519672775]
# Bugalagrande
# [-0.19737140614701204, -0.31216631688205626, -0.04329117056493921]
# Caicedonia
# [-0.23246320702820336, -0.30882530633707472, -0.0093681532556269403]
# Calima - Darién
# [-0.21228066950820776, -0.30349196336374779, 0.075393643674113719]
# Candelaria
# [-0.16049097026621367, -0.29006453375345809, 0.15891899930644715]
# Cartago
# [-0.25091166502535006, -0.32316915385239153, -0.096653894568209886]
# Dagua
# [-0.22252619260042428, -0.33842645055081966, 0.093698025550750977]
# El Aguila
# [-0.22697995097031573, -0.45911217919989272, 0.29858937143385478]
# El Cairo
# [-0.29901823332937005, -0.5091677173080843, 0.18210025663335169]
# El Cerrito
# [-0.18408121328684574, -0.26725328382477009, -0.045065258989298182]
# El Dovio
# [-0.24085796200424728, -0.40577699411768653, 0.054787606552039458]
# Florida
# [-0.22208292387921411, -0.302937203185908, -0.026299205036301662]
# Ginebra
# [-0.19233035027613699, -0.29347839644940027, 0.070594901107355681]
# Guacarí
# [-0.22710817785411971, -0.29474963490311346, -0.027292178495315692]
# Jamundi
# [-0.16382633698922444, -0.26912591884111375, -0.018478446848776572]
# La Cumbre
# [-0.23011089438350857, -0.32514478820111559, 0.057323234448681246]
# La Unión
# [-0.1998826869258799, -0.2830764832242052, 0.0072514556454654766]
# La Victoria
# [-0.26925522037063571, -0.37632041328721011, 0.031904733055721224]
# Obando
# [-0.29125655654295174, -0.43510395549035025, 0.078095603325170404]
# Palmira
# [-0.145776445359628, -0.23438882547829831, -0.036255024008278375]
# Pradera
# [-0.27642717514370946, -0.35092931735464983, -0.041270298396862318]
# Restrepo
# [-0.23521211784004389, -0.32391541950798713, -0.0012038331517311429]
# Riofrío
# [-0.28253057599722875, -0.41121974640777281, 0.059582507284567821]
# Roldanillo
# [-0.21797469084853668, -0.29654362583968447, 0.02475937590532129]
# San Pedro
# [-0.22104843112652481, -0.32338511172679935, 0.069809255127993852]
# Sevilla
# [-0.2312821761603846, -0.32753387715883553, 0.033186880210474001]
# Toro
# [-0.27915453287184211, -0.41217073200708293, 0.024370759420880961]
# Trujillo
# [-0.29001448303356775, -0.43937843122434839, 0.13598244025030135]
# Tuluá
# [-0.17801455979932854, -0.256465270427297, -0.072077230967186753]
# Ulloa
# [-0.23382536948068985, -0.37481534258717175, -0.031065906123556197]
# Versalles
# [-0.23666746648491499, -0.39714501634178911, 0.36384567458161177]
# Vijes
# [-0.22779300678197714, -0.33557141539549118, 0.053404666243839119]
# Yotoco
# [-0.2363629204632765, -0.34525529367715557, 0.054656837349843015]
# [-0.27149392463899147, -0.62115712596862349, 0.81631091746280215]
# Santiago
# [-0.3322216248757161, -0.60933588926263405, -0.082260723758473805]
# Valle del Guamuez
# [-0.31581428461032396, -0.6265356567993341, 0.60836685063570706]
# Villagarzón
# [-0.29000897254989438, -0.75701781272266555, 0.14570479903612499]
# San Andrés
# [-0.14492133502326612, -0.29774273970250309, 0.59298985098464674]
# Providencia
# [-0.16936639381321292, -0.34745727038460528, 0.5461567245574972]
# Leticia
# [-0.24789098305505775, -0.41231512732430969, 0.2193643077999993]
# El encanto (CD)*
# [-0.34655230457988961, -0.59110882642345797, 0.8003557932745643]
# La chorrera (CD)
# [-0.25721257638481854, -0.72530640359444609, 0.75914261504267344]
# La pedrera (CD)
# [-0.34181145950381703, -0.62969362774266258, 0.80817320293049011]
# Miriti-Paraná (CD)*
# [0.24066829091364306, -0.58295084888937576, 0.92130823085001945]
# Puerto Alegria (CD)*
# [0.26776886803055733, -1.3038744047023045, 0.67732746440357916]
# Puerto Arica (CD)
# [-0.19036299243407878, -0.79598603256703049, 0.76103972307871104]
# Puerto Nariño
# [-0.37394894819287799, -0.73587287221394571, 0.46833714910291119]
# Puerto Santander (CD)*
# [-0.32891051648320285, -0.623342784861459, 0.43395392220491202]
# Tarapacá (CD)
# [-0.37443946367956038, -0.86147194443740194, 0.7374382734928]
# Inirida
# [-0.33282781224526775, -0.58983698637212045, 0.51839533242351554]
# Barranco Minas (CD)*
# [-0.38393451702492565, -0.78796618419273656, 0.49123811279902863]
# San Felipe (CD)*
# [-0.35431825313925586, -0.67783282597515104, 0.8230982466478638]
# Puerto Colombia (CD)
# [-0.54972641239152387, -1.0781584912321331, 0.70732166471632796]
# La Guadalupe (CD)*
# [-0.36042840789412878, -0.74936574879511597, 0.86051850654043249]
# Cacahual (CD)*
# [-0.43834785906825813, -0.88150206275970611, 0.77000440714379081]
# San José del Guaviare
# [-0.28555728380830048, -0.52776010844928989, 0.48360749859110214]
# Calamar
# [-0.39794628663895326, -0.61924401106567006, 0.23108378318074804]
# El Retorno*
# [-0.58790340041375144, -0.75172407317456935, -0.084040270737184758]
# Miraflores
# [-0.26232549066175054, -0.50846714228001955, 0.68185881434133544]
# Mitú
# [-0.45788523578828982, -0.57004964232370847, 0.020020300168414856]
# Caruru*
# [-0.32915484360074193, -0.53079226867025042, -0.080298903236309199]
# Taraira
# [-0.32454319627132205, -0.75527437842826151, 0.53616906353697269]
# Papunaua (CD)*
# [-0.31485558629485161, -0.84153851377833333, 0.81833823206317868]
# Yavaraté
# [-0.2017125814609943, -0.94340105136647623, 0.77058317638886953]
# Puerto Carreño
# [-0.27560752805994748, -0.53111765936738164, 0.14592993371148483]
# La Primavera*
# [-0.44755963430255913, -0.78446627994345608, 0.49312742376687291]
# Santa Rosalia
# [-0.30811578321443933, -0.77893314604621011, 0.12325495473447556]
# Cumaribo
# [-0.40640615089917304, -0.83285152481114066, 0.47763677694612389]

# %% [markdown]
# # Clustering, K-Means

# %%
#algoritmo para buscar clusters en una muestra dada
def clustering( nClusters, data ):
    i = j = 0
    dim = len(data[0])
    muestra = len(data)
    indexClusters = -np.ones(muestra)
    clusterPoints = 10*np.random.random((nClusters, dim))
    #clusterPoints = np.array([[0,0],[100,100]])
    termino = False
    while termino == False :
        hayClustersVacios = False
        indexClusters = -np.ones(muestra)
        i = 0
        for i in range(muestra):
            dmin = np.linalg.norm(data[i] - clusterPoints[0])
            nmin = 0
            for j in range(1, nClusters):
                n = np.linalg.norm(data[i] - clusterPoints[j])
                if n < dmin:
                    dmin = n
                    nmin = j
            indexClusters[i] = nmin
        
        newClusters = np.zeros((nClusters,dim))
        k = 0
        for k in range(nClusters):
            index = where(indexClusters == k)
            if len(index[0]) != 0 :
                newClusters[k] = np.mean(data[index], linspace(0,dim,1))
            else: 
                hayClustersVacios = True
        if (newClusters == clusterPoints).all():
            #c = where((newClusters == [0.,0.]).all())
            #print "\n", newClusters, c
            #if len(c[0]) != 0:
             #   newClusters = 10*np.random.random((nClusters, dim))
            #else:
            if hayClustersVacios == True:
                newClusters = 10*np.random.random((nClusters, dim))
            else:    
                termino = True
        #print indexClusters
        #print clusterPoints
        clusterPoints = newClusters
    k = 0       
    return [[data[where(indexClusters == k)] for k in range(nClusters)], clusterPoints]

# %%
#Calcula la distancia promedio de un conjunto de datos dado
def distProm(data):
    i = j = 0
    dim = len(data[0])
    muestra = len(data)
    suma = 0
    count = 0
    for i in range(muestra):
        for j in range(muestra):
            if(i!=j):
                suma += np.linalg.norm(data[i]-data[j])
                count += 1
    
    return suma/count

# %%
#Primero se calculan 2 clusters
clusters2 = clustering(2, arrayTasas)

# %%
#Se miran los promedios de distancia en cada cluster
prom_2_1 = distProm(np.array(clusters2[0][0]))
prom_2_2 = distProm(np.array(clusters2[0][1]))
print "Con 2 Clusters\n\nPromedio de distancias del Cluster1"
print prom_2_1
print "\nPromedio de distancias del Cluster2"
print prom_2_2
print "\nPromedio ambos promedios (o desviaciones)"
print (prom_2_1 + prom_2_2)/2
# Out:
# Con 2 Clusters
#
# Promedio de distancias del Cluster1
# 0.250085261607
#
# Promedio de distancias del Cluster2
# 0.346163599607
#
# Promedio ambos promedios (o desviaciones)
# 0.298124430607

# %% [markdown]
# Estos numeros pequeños son muy razonables ya que nos encontramos en un espacio de solo 4 dimensiones con 1123 puntos distribuidos en un espacio con rango restringido (de 0 a 1)

# %%
#Ahora con 3 clusters
clusters3 = clustering(3, arrayTasas)

# %%
#Se miran los promedios de distancia en cada cluster
prom_3_1 = distProm(np.array(clusters3[0][0]))
prom_3_2 = distProm(np.array(clusters3[0][1]))
prom_3_3 = distProm(np.array(clusters3[0][2]))
print "Con 3 Clusters\n\nPromedio de distancias del Cluster1"
print prom_3_1
print "\nPromedio de distancias del Cluster2"
print prom_3_2
print "\nPromedio de distancias del Cluster3"
print prom_3_3
print "\nPromedio todos los promedios (o desviaciones)"
print (prom_3_1+prom_3_2+prom_3_3)/3
# Out:
# Con 3 Clusters
#
# Promedio de distancias del Cluster1
# 0.244982324507
#
# Promedio de distancias del Cluster2
# 0.191837654199
#
# Promedio de distancias del Cluster3
# 0.349605527251
#
# Promedio todos los promedios (o desviaciones)
# 0.262141835319

# %% [markdown]
# Aquí los promedios disminuyeron un poco, lo que quiere decir que el conjunto de datos está mejor caracterizado como formado por 3 Clusters que por 2 (Por ahora)

# %%
#Ahora con 4 clusters
clusters4 = clustering(4, arrayTasas)

# %%
#Se miran los promedios de distancia en cada cluster
prom_4_1 = distProm(np.array(clusters4[0][0]))
prom_4_2 = distProm(np.array(clusters4[0][1]))
prom_4_3 = distProm(np.array(clusters4[0][2]))
prom_4_4 = distProm(np.array(clusters4[0][3]))

print "Con 4 Clusters\n\nPromedio de distancias del Cluster1"
print prom_4_1
print "\nPromedio de distancias del Cluster2"
print prom_4_2
print "\nPromedio de distancias del Cluster3"
print prom_4_3
print "\nPromedio de distancias del Cluster4"
print prom_4_4
print "\nPromedio todos los promedios (o desviaciones)"
print (prom_4_1+prom_4_2+prom_4_3+ prom_4_4)/4
# Out:
# Con 4 Clusters
#
# Promedio de distancias del Cluster1
# 0.213365293112
#
# Promedio de distancias del Cluster2
# 0.230802185452
#
# Promedio de distancias del Cluster3
# 0.347348229418
#
# Promedio de distancias del Cluster4
# 0.179534505404
#
# Promedio todos los promedios (o desviaciones)
# 0.242762553346

# %% [markdown]
# Los promedios disminuyeron otra vez, lo que significa que el conjunto de datos está mejor caracterizado como formado por 4 Clusters que por 2 o por 3 (Por ahora).

# %%
#Ahora con 5 clusters
clusters5 = clustering(5, arrayTasas)

# %%
#Se miran los promedios de distancia en cada cluster
prom_5_1 = distProm(np.array(clusters5[0][0]))
prom_5_2 = distProm(np.array(clusters5[0][1]))
prom_5_3 = distProm(np.array(clusters5[0][2]))
prom_5_4 = distProm(np.array(clusters5[0][3]))
prom_5_5 = distProm(np.array(clusters5[0][4]))

print "Con 5 Clusters\n\nPromedio de distancias del Cluster1"
print prom_5_1
print "\nPromedio de distancias del Cluster2"
print prom_5_2
print "\nPromedio de distancias del Cluster3"
print prom_5_3
print "\nPromedio de distancias del Cluster4"
print prom_5_4
print "\nPromedio de distancias del Cluster5"
print prom_5_5
print "\nPromedio todos los promedios (o desviaciones)"
print (prom_5_1+prom_5_2+prom_5_3+ prom_5_4)/5
# Out:
# Con 5 Clusters
#
# Promedio de distancias del Cluster1
# 0.213182887777
#
# Promedio de distancias del Cluster2
# 0.233437603284
#
# Promedio de distancias del Cluster3
# 0.167252583778
#
# Promedio de distancias del Cluster4
# 0.142388976612
#
# Promedio de distancias del Cluster5
# 0.343493075734
#
# Promedio todos los promedios (o desviaciones)
# 0.15125241029

# %% [markdown]
# Otra vez, los promedios disminuyeron (en promedio) respecto a los promedios de 4 Clusters lo que significa que el conjunto de datos está mejor caracterizado como formado por 5 Clusters que por 4, por 3 o por 2 clusters.

# %% [markdown]
# ## Finalmente se puede concluir que el conjunto de historiales de los departamentos está mejor caracterizado como formado por 5 clusters. El promedio de distancias de cada uno de estos clusters es razonable debido al espacio restringido donde se encuentra y a la muestra que se presenta.
